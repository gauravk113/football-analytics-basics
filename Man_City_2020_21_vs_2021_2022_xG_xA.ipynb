# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib import gridspec
import matplotlib.patheffects as path_effects
from highlight_text import HighlightText, ax_text, fig_text

# %%
pip install highlight-text
# Out:
# Requirement already satisfied: highlight-text in /usr/local/lib/python3.7/dist-packages (0.2)

# %%
from highlight_text import HighlightText, ax_text, fig_text

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a78901ea-e22a-4ec5-85b1-091f1f89c31a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a78901ea-e22a-4ec5-85b1-091f1f89c31a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving city_xG_xA_2022.csv to city_xG_xA_2022.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded["city_xG_xA_2022.csv"]))
df
# Out:
#           Date           Time  Round  Day Venue Result  GF  GA  \
# 0   2021-01-20  18:00 (23:30)      1  Wed  Home      W   2   0
# 1   2020-09-21  20:15 (00:45)      2  Mon  Away      W   3   1
# 2   2020-09-27  16:30 (21:00)      3  Sun  Home      L   2   5
# 3   2020-10-03  17:30 (22:00)      4  Sat  Away      D   1   1
# 4   2020-10-17  17:30 (22:00)      5  Sat  Home      W   1   0
# ..         ...            ...    ...  ...   ...    ...  ..  ..
# 61  2022-02-09  19:45 (01:15)     24  Wed  Home      W   2   0
# 62  2022-02-12  17:30 (23:00)     25  Sat  Away      W   4   0
# 63  2022-02-19  17:30 (23:00)     26  Sat  Home      L   2   3
# 64  2022-02-26  17:30 (23:00)     27  Sat  Away      W   1   0
# 65  2022-03-06  16:30 (22:00)     28  Sun  Home      W   4   1
#
#           Opponent   xG  xGA  Poss  Attendance          Captain Formation  \
# 0      Aston Villa  4.3  0.8    68         NaN  Kevin De Bruyne     4-3-3
# 1           Wolves  1.9  1.0    65         NaN      Fernandinho   4-2-3-1
# 2   Leicester City  0.9  2.6    72         NaN      Fernandinho   4-2-3-1
# 3     Leeds United  1.5  1.7    48         NaN  Kevin De Bruyne     4-3-3
# 4          Arsenal  1.5  0.9    59         NaN  Raheem Sterling     3-5-2
# ..             ...  ...  ...   ...         ...              ...       ...
# 61       Brentford  2.0  0.7    75     51658.0       Rúben Dias     4-3-3
# 62    Norwich City  4.6  0.5    72     27010.0      Fernandinho     4-3-3
# 63       Tottenham  2.2  1.8    71     53201.0   İlkay Gündoğan     4-3-3
# 64         Everton  1.6  0.8    67     39105.0   İlkay Gündoğan     4-3-3
# 65  Manchester Utd  2.7  0.5    69     53165.0  Kevin De Bruyne     4-3-3
#
#            Referee  Match Report  Notes
# 0    Jonathan Moss  Match Report    NaN
# 1   Andre Marriner  Match Report    NaN
# 2   Michael Oliver  Match Report    NaN
# 3        Mike Dean  Match Report    NaN
# 4   Chris Kavanagh  Match Report    NaN
# ..             ...           ...    ...
# 61  Darren England  Match Report    NaN
# 62  Andre Marriner  Match Report    NaN
# 63  Anthony Taylor  Match Report    NaN
# 64    Paul Tierney  Match Report    NaN
# 65  Michael Oliver  Match Report    NaN
#
# [66 rows x 18 columns]

# %%
#df = pd.read_csv('city xG xA 2022.csv')

# %%
df
# Out:
#           Date           Time  Round  Day Venue Result  GF  GA  \
# 0   2021-01-20  18:00 (23:30)      1  Wed  Home      W   2   0
# 1   2020-09-21  20:15 (00:45)      2  Mon  Away      W   3   1
# 2   2020-09-27  16:30 (21:00)      3  Sun  Home      L   2   5
# 3   2020-10-03  17:30 (22:00)      4  Sat  Away      D   1   1
# 4   2020-10-17  17:30 (22:00)      5  Sat  Home      W   1   0
# ..         ...            ...    ...  ...   ...    ...  ..  ..
# 61  2022-02-09  19:45 (01:15)     24  Wed  Home      W   2   0
# 62  2022-02-12  17:30 (23:00)     25  Sat  Away      W   4   0
# 63  2022-02-19  17:30 (23:00)     26  Sat  Home      L   2   3
# 64  2022-02-26  17:30 (23:00)     27  Sat  Away      W   1   0
# 65  2022-03-06  16:30 (22:00)     28  Sun  Home      W   4   1
#
#           Opponent   xG  xGA  Poss  Attendance          Captain Formation  \
# 0      Aston Villa  4.3  0.8    68         NaN  Kevin De Bruyne     4-3-3
# 1           Wolves  1.9  1.0    65         NaN      Fernandinho   4-2-3-1
# 2   Leicester City  0.9  2.6    72         NaN      Fernandinho   4-2-3-1
# 3     Leeds United  1.5  1.7    48         NaN  Kevin De Bruyne     4-3-3
# 4          Arsenal  1.5  0.9    59         NaN  Raheem Sterling     3-5-2
# ..             ...  ...  ...   ...         ...              ...       ...
# 61       Brentford  2.0  0.7    75     51658.0       Rúben Dias     4-3-3
# 62    Norwich City  4.6  0.5    72     27010.0      Fernandinho     4-3-3
# 63       Tottenham  2.2  1.8    71     53201.0   İlkay Gündoğan     4-3-3
# 64         Everton  1.6  0.8    67     39105.0   İlkay Gündoğan     4-3-3
# 65  Manchester Utd  2.7  0.5    69     53165.0  Kevin De Bruyne     4-3-3
#
#            Referee  Match Report  Notes
# 0    Jonathan Moss  Match Report    NaN
# 1   Andre Marriner  Match Report    NaN
# 2   Michael Oliver  Match Report    NaN
# 3        Mike Dean  Match Report    NaN
# 4   Chris Kavanagh  Match Report    NaN
# ..             ...           ...    ...
# 61  Darren England  Match Report    NaN
# 62  Andre Marriner  Match Report    NaN
# 63  Anthony Taylor  Match Report    NaN
# 64    Paul Tierney  Match Report    NaN
# 65  Michael Oliver  Match Report    NaN
#
# [66 rows x 18 columns]

# %%
df.head()
# Out:
#          Date           Time  Round  Day Venue Result  GF  GA        Opponent  \
# 0  2021-01-20  18:00 (23:30)      1  Wed  Home      W   2   0     Aston Villa
# 1  2020-09-21  20:15 (00:45)      2  Mon  Away      W   3   1          Wolves
# 2  2020-09-27  16:30 (21:00)      3  Sun  Home      L   2   5  Leicester City
# 3  2020-10-03  17:30 (22:00)      4  Sat  Away      D   1   1    Leeds United
# 4  2020-10-17  17:30 (22:00)      5  Sat  Home      W   1   0         Arsenal
#
#     xG  xGA  Poss  Attendance          Captain Formation         Referee  \
# 0  4.3  0.8    68         NaN  Kevin De Bruyne     4-3-3   Jonathan Moss
# 1  1.9  1.0    65         NaN      Fernandinho   4-2-3-1  Andre Marriner
# 2  0.9  2.6    72         NaN      Fernandinho   4-2-3-1  Michael Oliver
# 3  1.5  1.7    48         NaN  Kevin De Bruyne     4-3-3       Mike Dean
# 4  1.5  0.9    59         NaN  Raheem Sterling     3-5-2  Chris Kavanagh
#
#    Match Report  Notes
# 0  Match Report    NaN
# 1  Match Report    NaN
# 2  Match Report    NaN
# 3  Match Report    NaN
# 4  Match Report    NaN

# %%
df['roll_xG'] = df['xG'].rolling(5, center=False).mean()
df['roll_xGA'] = df['xGA'].rolling(5, center=False).mean()
df
# Out:
#           Date           Time  Round  Day Venue Result  GF  GA  \
# 0   2021-01-20  18:00 (23:30)      1  Wed  Home      W   2   0
# 1   2020-09-21  20:15 (00:45)      2  Mon  Away      W   3   1
# 2   2020-09-27  16:30 (21:00)      3  Sun  Home      L   2   5
# 3   2020-10-03  17:30 (22:00)      4  Sat  Away      D   1   1
# 4   2020-10-17  17:30 (22:00)      5  Sat  Home      W   1   0
# ..         ...            ...    ...  ...   ...    ...  ..  ..
# 61  2022-02-09  19:45 (01:15)     24  Wed  Home      W   2   0
# 62  2022-02-12  17:30 (23:00)     25  Sat  Away      W   4   0
# 63  2022-02-19  17:30 (23:00)     26  Sat  Home      L   2   3
# 64  2022-02-26  17:30 (23:00)     27  Sat  Away      W   1   0
# 65  2022-03-06  16:30 (22:00)     28  Sun  Home      W   4   1
#
#           Opponent   xG  xGA  Poss  Attendance          Captain Formation  \
# 0      Aston Villa  4.3  0.8    68         NaN  Kevin De Bruyne     4-3-3
# 1           Wolves  1.9  1.0    65         NaN      Fernandinho   4-2-3-1
# 2   Leicester City  0.9  2.6    72         NaN      Fernandinho   4-2-3-1
# 3     Leeds United  1.5  1.7    48         NaN  Kevin De Bruyne     4-3-3
# 4          Arsenal  1.5  0.9    59         NaN  Raheem Sterling     3-5-2
# ..             ...  ...  ...   ...         ...              ...       ...
# 61       Brentford  2.0  0.7    75     51658.0       Rúben Dias     4-3-3
# 62    Norwich City  4.6  0.5    72     27010.0      Fernandinho     4-3-3
# 63       Tottenham  2.2  1.8    71     53201.0   İlkay Gündoğan     4-3-3
# 64         Everton  1.6  0.8    67     39105.0   İlkay Gündoğan     4-3-3
# 65  Manchester Utd  2.7  0.5    69     53165.0  Kevin De Bruyne     4-3-3
#
#            Referee  Match Report  Notes  roll_xG  roll_xGA
# 0    Jonathan Moss  Match Report    NaN      NaN       NaN
# 1   Andre Marriner  Match Report    NaN      NaN       NaN
# 2   Michael Oliver  Match Report    NaN      NaN       NaN
# 3        Mike Dean  Match Report    NaN      NaN       NaN
# 4   Chris Kavanagh  Match Report    NaN     2.02      1.40
# ..             ...           ...    ...      ...       ...
# 61  Darren England  Match Report    NaN     1.38      0.72
# 62  Andre Marriner  Match Report    NaN     2.14      0.76
# 63  Anthony Taylor  Match Report    NaN     2.22      0.92
# 64    Paul Tierney  Match Report    NaN     2.40      0.98
# 65  Michael Oliver  Match Report    NaN     2.62      0.86
#
# [66 rows x 20 columns]

# %%
#Season 1
s1 = df[0:38]

#Season 2
s2 = df[38:]

# %%
s1
# Out:
#           Date           Time  Round  Day Venue Result  GF  GA  \
# 0   2021-01-20  18:00 (23:30)      1  Wed  Home      W   2   0
# 1   2020-09-21  20:15 (00:45)      2  Mon  Away      W   3   1
# 2   2020-09-27  16:30 (21:00)      3  Sun  Home      L   2   5
# 3   2020-10-03  17:30 (22:00)      4  Sat  Away      D   1   1
# 4   2020-10-17  17:30 (22:00)      5  Sat  Home      W   1   0
# 5   2020-10-24  12:30 (17:00)      6  Sat  Away      D   1   1
# 6   2020-10-31  12:30 (18:00)      7  Sat  Away      W   1   0
# 10          Fulham  3.0  0.2    69         NaN  Kevin De Bruyne   4-2-3-1
# 11  Manchester Utd  1.2  1.0    54         NaN      Fernandinho   4-2-3-1
# 12       West Brom  1.9  0.3    77         NaN  Kevin De Bruyne   4-2-3-1
# 13     Southampton  1.1  1.0    52         NaN  Kevin De Bruyne   4-2-3-1
# 14   Newcastle Utd  1.8  0.3    75         NaN  Kevin De Bruyne    4-3-3◆
# 15         Everton  1.5  1.0    71         NaN  Raheem Sterling     4-3-3
# 16         Chelsea  2.4  0.8    46         NaN  Kevin De Bruyne   4-2-3-1
# 17        Brighton  2.6  0.2    65         NaN  Kevin De Bruyne     4-3-3
# 18  Crystal Palace  0.9  0.0    72         NaN      Fernandinho     4-3-3
# 19       West Brom  2.0  0.4    77         NaN  Raheem Sterling     4-3-3
# 20   Sheffield Utd  1.2  0.2    74         NaN      Fernandinho     4-3-3
# 21         Burnley  2.6  0.1    74         NaN  Raheem Sterling     4-3-3
# 22       Liverpool  3.1  1.3    44         NaN  Raheem Sterling     4-3-3
# 23       Tottenham  2.9  0.6    61         NaN  Raheem Sterling     4-3-3
# 24         Arsenal  2.0  0.3    56         NaN      Fernandinho     4-3-3
# 25        West Ham  0.6  1.6    63         NaN      Fernandinho     4-3-3
# 26  Manchester Utd  1.5  1.6    66         NaN  Kevin De Bruyne     4-3-3
# 27          Fulham  2.3  0.3    54         NaN    Sergio Agüero     3-4-3
# 28          Wolves  2.3  0.4    73         NaN  Kevin De Bruyne     4-3-3
# 29  Leicester City  2.3  0.4    56         NaN      Fernandinho   4-2-3-1
# 30    Leeds United  2.4  0.3    71         NaN      Fernandinho     4-3-3
# 31     Aston Villa  1.4  0.7    71         NaN   İlkay Gündoğan     4-3-3
# 32     Southampton  2.7  1.8    57         NaN      Fernandinho     4-3-3
# 33  Crystal Palace  2.1  0.8    67         NaN      Fernandinho   4-4-1-1
# 34         Chelsea  2.2  0.8    49         NaN  Raheem Sterling     3-5-2
# 35   Newcastle Utd  1.3  2.2    82         NaN  Raheem Sterling     4-3-3
# 36        Brighton  1.0  1.4    37      7945.0   İlkay Gündoğan     4-3-3
# 37         Everton  2.6  1.2    68     10000.0      Fernandinho     4-3-3
#
#             Referee  Match Report  Notes  roll_xG  roll_xGA
# 0     Jonathan Moss  Match Report    NaN      NaN       NaN
# 1    Andre Marriner  Match Report    NaN      NaN       NaN
# 2    Michael Oliver  Match Report    NaN      NaN       NaN
# 3         Mike Dean  Match Report    NaN      NaN       NaN
# 4    Chris Kavanagh  Match Report    NaN     2.02      1.40
# 5    Anthony Taylor  Match Report    NaN     1.38      1.34
# 6    Michael Oliver  Match Report    NaN     1.30      1.24
# 7      Craig Pawson  Match Report    NaN     1.44      1.00
# 8         Mike Dean  Match Report    NaN     1.40      0.80
# 9         Lee Mason  Match Report    NaN     1.66      0.70
# 10    Jonathan Moss  Match Report    NaN     2.04      0.64
# 11   Chris Kavanagh  Match Report    NaN     1.98      0.74
# 12     Peter Bankes  Match Report    NaN     2.04      0.52
# 13        Mike Dean  Match Report    NaN     2.00      0.58
# 14   Andre Marriner  Match Report    NaN     1.80      0.56
# 15   Andre Marriner  Match Report    NaN     1.50      0.72
# 16   Anthony Taylor  Match Report    NaN     1.74      0.68
# 17   Darren England  Match Report    NaN     1.88      0.66
# 18        Lee Mason  Match Report    NaN     1.84      0.46
# 19   Chris Kavanagh  Match Report    NaN     1.88      0.48
# 20      David Coote  Match Report    NaN     1.82      0.32
# 21  Martin Atkinson  Match Report    NaN     1.86      0.18
# 22   Michael Oliver  Match Report    NaN     1.96      0.40
# 23     Paul Tierney  Match Report    NaN     2.36      0.52
# 24    Jonathan Moss  Match Report    NaN     2.36      0.50
# 25   Michael Oliver  Match Report    NaN     2.24      0.78
# 26   Anthony Taylor  Match Report    NaN     2.02      1.08
# 27   Andre Marriner  Match Report    NaN     1.86      0.88
# 28   Chris Kavanagh  Match Report    NaN     1.74      0.84
# 29   Anthony Taylor  Match Report    NaN     1.80      0.86
# 30   Andre Marriner  Match Report    NaN     2.16      0.60
# 31     Peter Bankes  Match Report    NaN     2.14      0.42
# 32    Jonathan Moss  Match Report    NaN     2.22      0.72
# 33      David Coote  Match Report    NaN     2.18      0.80
# 34   Anthony Taylor  Match Report    NaN     2.16      0.88
# 35     Kevin Friend  Match Report    NaN     1.94      1.26
# 36   Stuart Attwell  Match Report    NaN     1.86      1.40
# 37   Michael Oliver  Match Report    NaN     1.84      1.28

# %%
s2
# Out:
#           Date           Time  Round  Day Venue Result  GF  GA  \
# 38  2021-08-15  16:30 (21:00)      1  Sun  Away      L   0   1
# 39  2021-08-21  15:00 (19:30)      2  Sat  Home      W   5   0
# 40  2021-08-28  12:30 (17:00)      3  Sat  Home      W   5   0
# 41  2021-09-11  15:00 (19:30)      4  Sat  Away      W   1   0
# 42  2021-09-18  15:00 (19:30)      5  Sat  Home      D   0   0
# 43  2021-09-25  12:30 (17:00)      6  Sat  Away      W   1   0
# 44  2021-10-03  16:30 (21:00)      7  Sun  Away      D   2   2
# 45  2021-10-16  15:00 (19:30)      8  Sat  Home      W   2   0
# 46  2021-10-23  17:30 (22:00)      9  Sat  Away      W   4   1
# 47  2021-10-30  15:00 (19:30)     10  Sat  Home      L   0   2
# 48  2021-11-06  12:30 (18:00)     11  Sat  Away      W   2   0
# 49  2021-11-21  14:00 (19:30)     12  Sun  Home      W   3   0
# 50  2021-11-28  14:00 (19:30)     13  Sun  Home      W   2   1
# 51  2021-12-01  20:15 (01:45)     14  Wed  Away      W   2   1
# 52  2021-12-04  17:30 (23:00)     15  Sat  Away      W   3   1
# 53  2021-12-11  12:30 (18:00)     16  Sat  Home      W   1   0
# 54  2021-12-14  20:00 (01:30)     17  Tue  Home      W   7   0
# 55  2021-12-19  14:15 (19:45)     18  Sun  Away      W   4   0
# 56  2021-12-26  15:00 (20:30)     19  Sun  Home      W   6   3
# 57  2021-12-29  20:15 (01:45)     20  Wed  Away      W   1   0
# 58  2022-01-01  12:30 (18:00)     21  Sat  Away      W   2   1
# 59  2022-01-15  12:30 (18:00)     22  Sat  Home      W   1   0
# 60  2022-01-22  17:30 (23:00)     23  Sat  Away      D   1   1
# 61  2022-02-09  19:45 (01:15)     24  Wed  Home      W   2   0
# 62  2022-02-12  17:30 (23:00)     25  Sat  Away      W   4   0
# 48   Michael Oliver  Match Report    NaN     2.02      1.00
# 49   Stuart Attwell  Match Report    NaN     2.24      0.86
# 50   Michael Oliver  Match Report    NaN     2.28      0.70
# 51        Mike Dean  Match Report    NaN     1.68      0.62
# 52     Simon Hooper  Match Report    NaN     2.18      0.54
# 53    Jonathan Moss  Match Report    NaN     2.48      0.46
# 54     Paul Tierney  Match Report    NaN     2.74      0.44
# 55  Martin Atkinson  Match Report    NaN     2.94      0.48
# 56   Chris Kavanagh  Match Report    NaN     3.44      0.78
# 57      David Coote  Match Report    NaN     2.88      0.70
# 58   Stuart Attwell  Match Report    NaN     2.54      0.86
# 59     Craig Pawson  Match Report    NaN     1.96      0.92
# 60     Simon Hooper  Match Report    NaN     1.66      1.06
# 61   Darren England  Match Report    NaN     1.38      0.72
# 62   Andre Marriner  Match Report    NaN     2.14      0.76
# 63   Anthony Taylor  Match Report    NaN     2.22      0.92
# 64     Paul Tierney  Match Report    NaN     2.40      0.98
# 65   Michael Oliver  Match Report    NaN     2.62      0.86

# %%
x1 = s1.Round.values
y1 = s1.xG.values

z1 = np.polyfit(x1, y1, 1)
p1 = np.poly1d(z1)

y2 = s1.xGA.values

z2 = np.polyfit(x1, y2, 1)
p2 = np.poly1d(z2)

x2 = s2.Round.values
y21 = s2.xG.values

z11 = np.polyfit(x2, y21, 1)
p11 = np.poly1d(z11)

y22 = s2.xGA.values

z22 = np.polyfit(x2, y22, 1)
p22 = np.poly1d(z22)

p22
# Out:
# poly1d([0.0107006 , 0.57698413])

# %%
fig = plt.figure(figsize=(48, 22))

spec = gridspec.GridSpec(ncols=2, nrows=1, figure=fig, wspace=0.03)

ax1 = fig.add_subplot(spec[0,0])
ax2 = fig.add_subplot(spec[0,1])

bg = "#141414"

title_font = "Open Sans"
body_font = 'Arial'

fig.set_facecolor(bg)

ax1.patch.set_facecolor(bg)
ax2.patch.set_facecolor(bg)

ax1.spines['bottom'].set_color('white')
ax1.spines['left'].set_color('white')

ax2.spines['bottom'].set_color('white')

for side in ['right','left','top','bottom']:
    ax1.spines['right'].set_visible(False)
    ax1.spines['top'].set_visible(False)
    ax2.spines['right'].set_visible(False)
    ax2.spines['top'].set_visible(False)
    ax2.spines['left'].set_visible(False)

ax1.spines['left'].set_linestyle((0,(8,8)))
ax1.spines['right'].set_linestyle((0,(8,8)))

ax2.tick_params(left=False)
ax2.tick_params(labelleft=False)

xt = [10,20,30]
yt = [0,0.5,1,1.5,2,2.5,3,3.5,4,4.5]
xt2 = [0,10,20,30]

xlabels1 = ['10', '20', '30']
ylabels = ['0', '0.5', '1', '1.5', '2', '2.5', '3', '3.5', '4']
xlabels2 = ['0', '10', '20', '30']

ax1.set_xticks(xt)
ax1.set_yticks(yt)
ax2.set_xticks(xt2)
ax2.set_yticks(yt)

ax1.set_xticklabels(xlabels1,color="white", size=24, fontweight="bold")
ax1.set_yticklabels(ylabels,color="white", size=24, fontweight="bold")

ax2.set_xticklabels(xlabels2,color="white", size=24, fontweight="bold")
ax2.set_yticklabels(ylabels,color="white", size=24, fontweight="bold")

ax1.set_xlim(0,39)
ax2.set_xlim(0,39)
ax1.set_ylim(0,5)
ax2.set_ylim(0,5)

ax1.grid(zorder=1,color="white",alpha=0.5, linestyle=((0,(5,5))))
ax2.grid(zorder=1,color="white",alpha=0.5, linestyle=((0,(5,5))))

#2020-21 Season:
ax1.scatter(s1['Round'], s1['roll_xG'], s=350, color='#2F2FFF', edgecolors=bg, zorder=3, linewidth=1)
ax1.plot(s1['Round'], s1['roll_xG'], color='#2F2FFF', zorder=2, lw=3, mec=bg)

ax1.scatter(s1['Round'], s1['roll_xGA'], s=350, color='#FF0000', edgecolors=bg, zorder=3, linewidth=1)
ax1.plot(s1['Round'], s1['roll_xGA'], color='#FF0000', zorder=2, lw=3, mec=bg)

ax1.plot(x1, p1(x1), color='#2F2FFF', ls='--', lw=4, mec=bg, alpha=0.8, zorder=1)

ax1.plot(x1, p2(x1), color='#FF0000', ls='--', lw=4, mec=bg, alpha=0.8, zorder=1)

#2021-22 Season:
ax2.scatter(s2['Round'], s2['roll_xG'], s=350, color='#2F2FFF', edgecolors=bg, zorder=3, linewidth=1)
ax2.plot(s2['Round'], s2['roll_xG'], color='#2F2FFF', zorder=2, lw=3, mec=bg)

ax2.scatter(s2['Round'], s2['roll_xGA'], s=350, color='#FF0000', edgecolors=bg, zorder=3, linewidth=1)
ax2.plot(s2['Round'], s2['roll_xGA'], color='#FF0000', zorder=2, lw=3, mec=bg)

ax2.plot(x2, p11(x2), color='#2F2FFF', ls='--', lw=4, mec=bg, alpha=0.8, zorder=1)

ax2.plot([20,20], [0,5], color='white', alpha=0.9, zorder=2, ls= '-.')

ax2.plot(x2, p22(x2), color='#FF0000', ls='--', lw=4, mec=bg, alpha=0.8, zorder=1)

#t = ax2.text(19.1,1.75, "Tuchel", rotation=90, color='white', size=45, fontfamily=body_font, zorder=2)

#t.set_path_effects([path_effects.withStroke(linewidth=4,foreground=bg)])

t1 = ax1.text(-3.5,0.75,"Expected Goals per Game", rotation=90, color='white', size=50, fontfamily=body_font, zorder=2)
t1.set_path_effects([path_effects.withStroke(linewidth=4,foreground=bg)])

t2 = ax1.text(35,-0.2, "Match Number", color='white', size=50, fontfamily=body_font, zorder=2)
t2.set_path_effects([path_effects.withStroke(linewidth=4,foreground=bg)])

title =\
fig.text(0.23,1.04, "How Man City's expected goals scored(xG) & expected goals against(xGA) trend over time",
        color = 'white',
        fontfamily = title_font,
        fontsize = 46,)



t3 = ax1.text(17,4.5, "2020/21", color='white', size=40, fontweight='bold', fontfamily=body_font, zorder=2)
t3.set_path_effects([path_effects.withStroke(linewidth=4,foreground=bg)])

t4 = ax2.text(15,4.5, "2021/22", color='white', size=40, fontweight='bold', fontfamily=body_font, zorder=2)
t4.set_path_effects([path_effects.withStroke(linewidth=4,foreground=bg)])

fig.text(0.315,0.97, "5 game rolling average | English Premier League | Seasons 2020/21 vs 2021/22", color='white', size=40, fontfamily=body_font, zorder=2)

ax1.text(-3.5,-0.35, "Data: Fbref", color='white', size=35, fontfamily=body_font)

ax2.text(30,-0.35, "By: The Full Time Whistle Co. (@theftwhistleco)", ha='center', color='white', size=35, fontfamily=body_font)
# Out:
# Text(30, -0.35, 'By: The Full Time Whistle Co. (@theftwhistleco)')
